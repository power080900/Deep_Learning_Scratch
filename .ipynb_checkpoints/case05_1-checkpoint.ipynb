# %% [markdown]
# # ch05. 오차역전파 법
# ## 1. 계산그래프
# ### 1) 노드와 엣지  </br>
# ![title](attachment:b21da1a2-0825-4c2c-a5bb-31997408e261.png)

# %% [markdown]
# #### 계산그래프로 풀어보기
#  문제 1 : 현빈군은 슈퍼에서 1개에 100원인 사과를 2개 샀습니다. 이때 지불 금액을 구하세요. 단 소비세가 10% 부과됩니다
#  ![image.png](attachment:b6872682-3af5-455b-8570-ceb8f8020552.png)

# %% [markdown]
#  문제 2 : 현빈군은 슈퍼에서 사과를 2개, 귤을 3개 샀습니다. 사과는 1개에 100원 귤은 1개에 150원입니다. 소비세가 10%일 떄 지불 금액을 구하세요
#  ![image.png](attachment:f778ca62-324e-4de0-be78-62dcef6fff49.png)

# %% [markdown]
# ### 2) 국소적 계산
# 계산 그래프의 특징 : '국소적 계산'을 전파함으로써 최종결과를 얻음
# 국소적 : 자신과 직접 관계된 작은범위
# 국소적 계산 : 전체에서 어떤 일이 벌어지든 상관없이 자신과 관계된 정보만으로 결과 출력 가능
# ![image.png](attachment:6e77e5e7-9c93-4d2f-859d-29bde1d40873.png)

# %% [markdown]
# ### 3) 왜 계산그래프로 묶는가?
# 미분의 효율적 계산 가능
#
# ![image.png](attachment:2065439d-724c-4805-9526-a84052fb9684.png)

# %% [markdown]
# ## 2. 연쇄법칙
# 4장의 순방향 미분과는 반대 방향인 오른쪽에서 왼쪽으로 전달하는 개념
# ![image.png](attachment:1ebcd5b6-c378-4208-9ff6-581cadf86688.png)
# ![image.png](attachment:6f695f1e-cd5d-478d-82d7-07e152ad3baa.png)
# ![image.png](attachment:309cf72b-7c05-4cbf-a323-d6c05b3e425f.png)

# %% [markdown]
# ### 1) 계산그래프의 역전파
# 순 방향과는 반대방향으로 국소적 미분을 곱한다

# %% [markdown]
# ### 2) 연쇄법칙
# 합성함수 : 여러 함수로 구성된 함수
# $ z = t^2 $
# $ t = x + y $

# %% [markdown]
# ### 3) 연쇄법칙과 계산 그래프
# 역전파의 계산 절차에서 노드로 들어온 입력신호에 해다당 노드의 국소적 미분(편미분)을 곱한 후 다음노드로 전달
# ![image.png](attachment:55ebe104-b70b-46d3-96b3-ede2d9598a95.png)
# ![image.png](attachment:642a48d9-28f1-4ebc-afb5-fa47ab43710e.png)

# %% [markdown]
# ## 3. 역전파
# ### 1) 덧셈 노드의 역전파
# $z = x+y$에 대한 역전파 구조
# 그래프
# ![image.png](attachment:d1fdf334-65ed-482c-b334-0a5e820c33d9.png)
# 생각의 확장(일반화)
# ![image.png](attachment:67bedd8d-103b-4e89-ae0d-ffbf2405949c.png)

# %% [markdown]
# 예시
# ![image.png](attachment:f340cac1-415b-4ccf-80cc-4bf29d581c9c.png)

# %% [markdown]
# ### 2) 곱셈노드의 역전파
# $z = xy$에 대한 역전파 구조
# 미분식
# ![image.png](attachment:4b6601d4-24ec-4071-aec6-bf7f9014cb6d.png)
# 계산 그래프
# ![image.png](attachment:b0996951-6ce9-4d0e-b11a-c709a0389410.png)
# 예시
# ![image.png](attachment:dfd05856-9f09-49be-80a6-72f8f0c41ce4.png)

# %% [markdown]
# ### 3) 사과쇼핑의 예
# ![image.png](attachment:695b84dd-3624-4100-b882-22e0476188d3.png)
